# %% [markdown]
# # Quadruped Locomotion: Reward Ablation
#
# 이 노트북은 `quadruped_locomotion.ipynb` 이후에 실행되는 **reward ablation 실험용** 노트북입니다.
#
# 이전 노트북:
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)]
# (https://colab.research.google.com/github/DrcdKAIST/RL_DEMO/blob/main/notebooks/0.quadruped_locomotion_basic.ipynb)
#
# 1. Task Reward (Velocity Tracking) 과 Termination Reward만 있는 가장 단순한 경우,
# 2. 1. 의 세팅에서 기본적인 Regularization Reward (Action smoothness, Joint velocity/acceleration ...) 가 추가된 경우,
# 3. 2. 의 세팅에서 Motion 및 Gait Regularization Reward 추가된 경우
#
# 총 세 가지의 세팅으로 변경시켜 보며 리워드들이 어떠한 영향을 주는지 확인합니다.
#
# 아래 셀부터 공통 세팅을 다시 수행합니다.

# %% [markdown]
# ---
#
# ## 0. Environment Setup
#
# Colab이면 `/content`를 기준 경로로 사용하고, 그렇지 않으면 현재 작업 디렉터리를 기준 경로로 사용합니다.

# %%
# Clone repository
import os, sys

import yaml

# Detect Colab by availability of /content or google.colab.
try:
    import google.colab  # noqa: F401
    in_colab = True
except Exception:
    in_colab = os.path.isdir("/content")

try:
    base_dir
except NameError:
    base_dir = "/content" if in_colab else os.getcwd()
os.chdir(base_dir)

repo_dir = os.path.join(base_dir, "RL_DEMO")

print(f"Base directory: {base_dir}")
print(f"Repo directory: {repo_dir}")

if not os.path.isdir(repo_dir):
  # !git clone https://github.com/DrcdKAIST/RL_DEMO.git --recursive
else:
  print("Cloned Directory already exists")

os.chdir(repo_dir)
print("Current Directory: ", os.getcwd())

sys.path.insert(0, repo_dir)
os.environ["MUJOCO_GL"] = "egl"
# Out:
# Base directory: /home/jaehyun/etc_ws/RL_DEMO/notebooks
# Repo directory: /home/jaehyun/etc_ws/RL_DEMO/notebooks/RL_DEMO
# Cloned Directory already exists
# Current Directory:  /home/jaehyun/etc_ws/RL_DEMO/notebooks/RL_DEMO

# %%
# Install dependencies
os.chdir(repo_dir + "/thirdParty/stable_baselines3")
# !pip install -e .[extra]
# !pip install torch numpy tensorboard gymnasium==0.29.1 mujoco==3.1.5 imageio[ffmpeg] pygments
# Out:
# Obtaining file:///home/jaehyun/etc_ws/RL_DEMO/notebooks/RL_DEMO/thirdParty/stable_baselines3
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: gymnasium<0.30,>=0.28.1 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from stable_baselines3==2.3.0) (0.29.1)
# Requirement already satisfied: numpy>=1.20 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from stable_baselines3==2.3.0) (2.4.1)
# Requirement already satisfied: torch>=1.13 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from stable_baselines3==2.3.0) (2.10.0)
# Requirement already satisfied: cloudpickle in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from stable_baselines3==2.3.0) (3.1.2)
# Requirement already satisfied: pandas in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from stable_baselines3==2.3.0) (3.0.0)
# Requirement already satisfied: matplotlib in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from stable_baselines3==2.3.0) (3.10.8)
# Requirement already satisfied: opencv-python in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from stable_baselines3==2.3.0) (4.13.0.92)
# Requirement already satisfied: pygame in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from stable_baselines3==2.3.0) (2.6.1)
# Requirement already satisfied: tensorboard>=2.9.1 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from stable_baselines3==2.3.0) (2.20.0)
# Requirement already satisfied: psutil in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from stable_baselines3==2.3.0) (7.2.2)
# Requirement already satisfied: tqdm in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from stable_baselines3==2.3.0) (4.67.3)
# Requirement already satisfied: rich in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from stable_baselines3==2.3.0) (14.3.1)
# Requirement already satisfied: shimmy~=1.3.0 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from shimmy[atari]~=1.3.0; extra == "extra"->stable_baselines3==2.3.0) (1.3.0)
# Requirement already satisfied: pillow in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from stable_baselines3==2.3.0) (12.1.0)
# Requirement already satisfied: autorom~=0.6.1 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable_baselines3==2.3.0) (0.6.1)
# Requirement already satisfied: click in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable_baselines3==2.3.0) (8.3.1)
# Requirement already satisfied: requests in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable_baselines3==2.3.0) (2.32.5)
# Requirement already satisfied: AutoROM.accept-rom-license in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable_baselines3==2.3.0) (0.6.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from gymnasium<0.30,>=0.28.1->stable_baselines3==2.3.0) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from gymnasium<0.30,>=0.28.1->stable_baselines3==2.3.0) (0.0.4)
# Requirement already satisfied: ale-py~=0.8.1 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from shimmy[atari]~=1.3.0; extra == "extra"->stable_baselines3==2.3.0) (0.8.1)
# Requirement already satisfied: absl-py>=0.4 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from tensorboard>=2.9.1->stable_baselines3==2.3.0) (2.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from tensorboard>=2.9.1->stable_baselines3==2.3.0) (1.76.0)
# Requirement already satisfied: markdown>=2.6.8 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from tensorboard>=2.9.1->stable_baselines3==2.3.0) (3.10.1)
# Requirement already satisfied: packaging in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from tensorboard>=2.9.1->stable_baselines3==2.3.0) (25.0)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from tensorboard>=2.9.1->stable_baselines3==2.3.0) (6.33.5)
# Requirement already satisfied: setuptools>=41.0.0 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from tensorboard>=2.9.1->stable_baselines3==2.3.0) (44.1.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from tensorboard>=2.9.1->stable_baselines3==2.3.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from tensorboard>=2.9.1->stable_baselines3==2.3.0) (3.1.5)
# Requirement already satisfied: filelock in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from torch>=1.13->stable_baselines3==2.3.0) (3.20.3)
# Requirement already satisfied: sympy>=1.13.3 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from torch>=1.13->stable_baselines3==2.3.0) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from torch>=1.13->stable_baselines3==2.3.0) (3.6.1)
# Requirement already satisfied: jinja2 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from torch>=1.13->stable_baselines3==2.3.0) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from torch>=1.13->stable_baselines3==2.3.0) (2026.1.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from torch>=1.13->stable_baselines3==2.3.0) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from torch>=1.13->stable_baselines3==2.3.0) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from torch>=1.13->stable_baselines3==2.3.0) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from torch>=1.13->stable_baselines3==2.3.0) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from torch>=1.13->stable_baselines3==2.3.0) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from torch>=1.13->stable_baselines3==2.3.0) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from torch>=1.13->stable_baselines3==2.3.0) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from torch>=1.13->stable_baselines3==2.3.0) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from torch>=1.13->stable_baselines3==2.3.0) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from torch>=1.13->stable_baselines3==2.3.0) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from torch>=1.13->stable_baselines3==2.3.0) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from torch>=1.13->stable_baselines3==2.3.0) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from torch>=1.13->stable_baselines3==2.3.0) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from torch>=1.13->stable_baselines3==2.3.0) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from torch>=1.13->stable_baselines3==2.3.0) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from torch>=1.13->stable_baselines3==2.3.0) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from torch>=1.13->stable_baselines3==2.3.0) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from cuda-bindings==12.9.4->torch>=1.13->stable_baselines3==2.3.0) (1.3.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from matplotlib->stable_baselines3==2.3.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from matplotlib->stable_baselines3==2.3.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from matplotlib->stable_baselines3==2.3.0) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from matplotlib->stable_baselines3==2.3.0) (1.4.9)
# Requirement already satisfied: pyparsing>=3 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from matplotlib->stable_baselines3==2.3.0) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from matplotlib->stable_baselines3==2.3.0) (2.9.0.post0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from rich->stable_baselines3==2.3.0) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from rich->stable_baselines3==2.3.0) (2.19.2)
# Requirement already satisfied: importlib-resources in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from ale-py~=0.8.1->shimmy[atari]~=1.3.0; extra == "extra"->stable_baselines3==2.3.0) (6.5.2)
# Requirement already satisfied: mdurl~=0.1 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->stable_baselines3==2.3.0) (0.1.2)
# Requirement already satisfied: six>=1.5 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib->stable_baselines3==2.3.0) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from sympy>=1.13.3->torch>=1.13->stable_baselines3==2.3.0) (1.3.0)
# Requirement already satisfied: markupsafe>=2.1.1 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable_baselines3==2.3.0) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from requests->autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable_baselines3==2.3.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from requests->autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable_baselines3==2.3.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from requests->autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable_baselines3==2.3.0) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from requests->autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable_baselines3==2.3.0) (2026.1.4)
# Building wheels for collected packages: stable_baselines3
#   Building editable for stable_baselines3 (pyproject.toml) ... done
#   Created wheel for stable_baselines3: filename=stable_baselines3-2.3.0-0.editable-py3-none-any.whl size=6381 sha256=2106b8e4de6973904452953da0d796a39fe7008437c9d30316bbc7569db099c5
#   Stored in directory: /tmp/pip-ephem-wheel-cache-gk3g9z79/wheels/c6/fc/56/26a54a9f6b94b4cf616c2dedeafe4df25d4be42386578fecd2
# Successfully built stable_baselines3
# Installing collected packages: stable_baselines3
#   Attempting uninstall: stable_baselines3
#     Found existing installation: stable_baselines3 2.3.0
#     Can't uninstall 'stable_baselines3'. No files were found to uninstall.
# Successfully installed stable_baselines3-2.3.0
#
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: torch in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (2.10.0)
# Requirement already satisfied: numpy in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (2.4.1)
# Requirement already satisfied: tensorboard in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (2.20.0)
# Requirement already satisfied: gymnasium==0.29.1 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (0.29.1)
# Requirement already satisfied: mujoco==3.1.5 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (3.1.5)
# Requirement already satisfied: pygments in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (2.19.2)
# Requirement already satisfied: imageio[ffmpeg] in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (2.37.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from gymnasium==0.29.1) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from gymnasium==0.29.1) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from gymnasium==0.29.1) (0.0.4)
# Requirement already satisfied: absl-py in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from mujoco==3.1.5) (2.4.0)
# Requirement already satisfied: etils[epath] in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from mujoco==3.1.5) (1.13.0)
# Requirement already satisfied: glfw in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from mujoco==3.1.5) (2.10.0)
# Requirement already satisfied: pyopengl in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from mujoco==3.1.5) (3.1.10)
# Requirement already satisfied: filelock in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from torch) (3.20.3)
# Requirement already satisfied: sympy>=1.13.3 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from torch) (2026.1.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from torch) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from torch) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from torch) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from torch) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from torch) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from torch) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from torch) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from torch) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from torch) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from torch) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from torch) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from torch) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from cuda-bindings==12.9.4->torch) (1.3.3)
# Requirement already satisfied: grpcio>=1.48.2 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from tensorboard) (1.76.0)
# Requirement already satisfied: markdown>=2.6.8 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from tensorboard) (3.10.1)
# Requirement already satisfied: packaging in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from tensorboard) (25.0)
# Requirement already satisfied: pillow in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from tensorboard) (12.1.0)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from tensorboard) (6.33.5)
# Requirement already satisfied: setuptools>=41.0.0 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from tensorboard) (44.1.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from tensorboard) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from tensorboard) (3.1.5)
# Requirement already satisfied: imageio-ffmpeg in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from imageio[ffmpeg]) (0.6.0)
# Requirement already satisfied: psutil in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from imageio[ffmpeg]) (7.2.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: markupsafe>=2.1.1 in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard) (3.0.3)
# Requirement already satisfied: importlib_resources in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from etils[epath]->mujoco==3.1.5) (6.5.2)
# Requirement already satisfied: zipp in /home/jaehyun/miniconda3/envs/rl_demo/lib/python3.11/site-packages (from etils[epath]->mujoco==3.1.5) (3.23.0)
#
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
from pathlib import Path
from IPython.display import HTML
from pygments import highlight
from pygments.lexers import PythonLexer
from pygments.formatters import HtmlFormatter
import inspect

def _render_code(code, title="code", max_height=400, bg="transparent", indent=16):
    style_name = "native" if in_colab else "friendly"
    formatter = HtmlFormatter(style=style_name, noclasses=True, linenos="inline")
    html = highlight(code, PythonLexer(), formatter)
    css = """
    <style>
    .highlight pre { margin: 0; text-align: left; }
    </style>
    """
    return HTML(f"""
    {css}
    <details>
      <summary>{title}</summary>
      <div style="margin-top:8px; margin-left:{indent}px; max-height:{max_height}px; overflow:auto; border:1px solid #ddd; padding:10px; background:{bg};">
        {html}
      </div>
    </details>
    """)


def show_code(path, max_height=400, title="code", bg="transparent"):
    code = Path(path).read_text()
    return _render_code(code, title=title, max_height=max_height, bg=bg)

def show_func(obj, max_height=400, title="code", bg="transparent"):
    code = inspect.getsource(obj)
    return _render_code(code, title=title, max_height=max_height, bg=bg)

# %% [markdown]
# ---
#
# ## 1-1. Reward Ablation Setup - Observations
#
# 실험 1,2의 경우 phase observation이 필요없기 때문에, 이를 제외하고, 실험 3의 경우 포함시켜야 하기 때문에 두가지 버전의 get_obs 함수를 준비하고이후 실험에 맞게 선택합니다.
#
# <div align="center">
#   <img src="rsc/phase.png">
# </div>

# %%
# Define alternate observation functions and monkey-patch (no file edits)
# NOTE: Edit the two functions below to run ablations.
import importlib
import src.go1_mujoco_env as go1_mujoco_env
importlib.reload(go1_mujoco_env)

Go1MujocoEnv = go1_mujoco_env.Go1MujocoEnv

# ---- Define variants ----

def _get_obs_with_phase(self):
    # TODO: update observation for ablation (with phase)
    dofs_position = self.data.qpos[7:].flatten() - self.model.key_qpos[0, 7:]
    velocity = self.data.qvel.flatten()
    base_linear_velocity = velocity[:3]
    base_angular_velocity = velocity[3:6]
    dofs_velocity = velocity[6:]
    desired_vel = self._desired_velocity
    last_action = self._last_action
    projected_gravity = self.projected_gravity

    curr_obs = np.concatenate(
        (
            base_linear_velocity * self._obs_scale["linear_velocity"],
            base_angular_velocity * self._obs_scale["angular_velocity"],
            projected_gravity,
            desired_vel * self._obs_scale["linear_velocity"],
            dofs_position * self._obs_scale["dofs_position"],
            dofs_velocity * self._obs_scale["dofs_velocity"],
            last_action,
            self._phase_sin,
        )
    ).clip(-self._clip_obs_threshold, self._clip_obs_threshold)

    return curr_obs


def _get_obs_without_phase(self):
    # TODO: update observation for ablation (without phase)
    dofs_position = self.data.qpos[7:].flatten() - self.model.key_qpos[0, 7:]
    velocity = self.data.qvel.flatten()
    base_linear_velocity = velocity[:3]
    base_angular_velocity = velocity[3:6]
    dofs_velocity = velocity[6:]
    desired_vel = self._desired_velocity
    last_action = self._last_action
    projected_gravity = self.projected_gravity

    curr_obs = np.concatenate(
        (
            base_linear_velocity * self._obs_scale["linear_velocity"],
            base_angular_velocity * self._obs_scale["angular_velocity"],
            projected_gravity,
            desired_vel * self._obs_scale["linear_velocity"],
            dofs_position * self._obs_scale["dofs_position"],
            dofs_velocity * self._obs_scale["dofs_velocity"],
            last_action,
        )
    ).clip(-self._clip_obs_threshold, self._clip_obs_threshold)

    return curr_obs

# %% [markdown]
# ---
#
# ## 1-2. Reward Ablation Setup
#
# 학습에 필요한 함수 및 변수들을 선언합니다.

# %%
# Check observation / action space

import importlib
import numpy as np
import os
import gc
import time
import imageio
import torch
from stable_baselines3 import PPO
from stable_baselines3.common.callbacks import EvalCallback, CheckpointCallback, CallbackList
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.vec_env import SubprocVecEnv
from IPython.display import Video, display
from pathlib import Path
import shutil

import src.go1_mujoco_env as go1_env

from src.utils.reward_logging_callback import RewardLoggingCallback
importlib.reload(go1_env)


DEFAULT_CAMERA_CONFIG = {
    "azimuth": 90.0,
    "distance": 3.0,
    "elevation": -25.0,
    "lookat": np.array([0., 0., 0.]),
    "fixedcamid": 0,
    "trackbodyid": -1,
    "type": 2,
}

policy_cfg_path = Path(repo_dir + "/src/params.yaml")
with policy_cfg_path.open("r", encoding="utf-8") as f:
    policy_cfg = yaml.safe_load(f)

# colab에서 실행하기 위한 설정
policy_cfg['n_envs'] = 12
policy_cfg['policy']['batch_size'] = 64

# Create environment (no rendering)
env = go1_env.Go1MujocoEnv(
    prj_path=repo_dir,
    render_mode=None,
)

obs, info = env.reset()

print(policy_cfg['n_envs'])
print(policy_cfg['policy']['batch_size'])
print(f"Observation shape: {np.array(obs).shape}\n")
print(f"Action space: {env.action_space}\n")
print(f"Observation space: {env.observation_space}\n")

def train_run(env_cfg_path=None):
    importlib.reload(go1_env)

    USE_PRETRAINED = False
    PRETRAINED_MODEL_PATH = f"{repo_dir}/models/pretrained3/final_model.zip"

    # Train
    MODEL_DIR = f"{repo_dir}/models"
    LOG_DIR = f"{repo_dir}/logs"

    os.makedirs(MODEL_DIR, exist_ok=True)
    os.makedirs(LOG_DIR, exist_ok=True)

    class Go1MujocoEnvPatched(go1_env.Go1MujocoEnv):
        def _get_obs(self):
            return (_get_obs_with_phase if use_phase else _get_obs_without_phase)(self)

    print("Use phase: ", use_phase)

    vec_env = make_vec_env(
        Go1MujocoEnvPatched,
        env_kwargs={"prj_path": repo_dir, "cfg_path": env_cfg_path},
        n_envs=policy_cfg["n_envs"],
        seed=policy_cfg["seed"],
        vec_env_cls=SubprocVecEnv,
    )


    train_time = time.strftime("%Y-%m-%d_%H-%M-%S")
    run_name = f"{train_time}"

    model_path = f"{MODEL_DIR}/{run_name}"
    print(
        f"Training on {policy_cfg['n_envs']} parallel training environments and saving models to '{model_path}'"
    )

    # 예: model_dir, model_name이 이미 정해져 있다고 가정
    if env_cfg_path is None:
        envs_src = Path(repo_dir) / "src" / "envs.yaml"
    else:
        envs_src = Path(env_cfg_path)
    envs_dst = Path(model_path) / "envs.yaml"
    envs_dst.parent.mkdir(parents=True, exist_ok=True)
    shutil.copy2(envs_src, envs_dst)

    print("Copied to:", envs_dst)


    checkpoint_callback = CheckpointCallback(
        save_freq=policy_cfg["policy"]["n_steps"] * policy_cfg["log"]["interval"],  # e.g. 100_000
        save_path=model_path,  # directory
        name_prefix="model",  # checkpoint_model_100000_steps.zip
        save_replay_buffer=False,
        save_vecnormalize=False,
    )

    eval_callback = EvalCallback(
        vec_env,
        best_model_save_path=model_path,
        log_path=LOG_DIR,
        eval_freq=policy_cfg["eval_freq"],
        n_eval_episodes=5,
        deterministic=True,
        render=False,
    )

    reward_logging_callback = RewardLoggingCallback()

    callbacks = CallbackList([
        eval_callback,
        checkpoint_callback,
        reward_logging_callback,
    ])

    if USE_PRETRAINED:
        print(f"Using Pretrained model from {PRETRAINED_MODEL_PATH}")
        model = PPO.load(path=PRETRAINED_MODEL_PATH, env=vec_env,
                    learning_rate=policy_cfg["policy"]["learning_rate"],
                    n_steps=policy_cfg["policy"]["n_steps"],
                    batch_size=policy_cfg["policy"]["batch_size"],
                    n_epochs=policy_cfg["policy"]["n_epochs"],
                    gamma=policy_cfg["policy"]["gamma"],
                    gae_lambda=policy_cfg["policy"]["gae_lambda"],
                    clip_range=policy_cfg["policy"]["clip_range"],
                    normalize_advantage=policy_cfg["policy"]["normalize_advantage"],
                    ent_coef=policy_cfg["policy"]["ent_coef"],
                    vf_coef=policy_cfg["policy"]["vf_coef"],
                    max_grad_norm=policy_cfg["policy"]["max_grad_norm"],
                    verbose=1,
                    tensorboard_log=LOG_DIR)
        model.tensorboard_log = LOG_DIR
    else:
        print("Training from Network model from scratch")
        model = PPO("MlpPolicy",
                    env=vec_env,
                    learning_rate=policy_cfg["policy"]["learning_rate"],
                    n_steps=policy_cfg["policy"]["n_steps"],
                    batch_size=policy_cfg["policy"]["batch_size"],
                    n_epochs=policy_cfg["policy"]["n_epochs"],
                    gamma=policy_cfg["policy"]["gamma"],
                    gae_lambda=policy_cfg["policy"]["gae_lambda"],
                    clip_range=policy_cfg["policy"]["clip_range"],
                    normalize_advantage=policy_cfg["policy"]["normalize_advantage"],
                    ent_coef=policy_cfg["policy"]["ent_coef"],
                    vf_coef=policy_cfg["policy"]["vf_coef"],
                    max_grad_norm=policy_cfg["policy"]["max_grad_norm"],
                    verbose=1,
                    tensorboard_log=LOG_DIR)

    model.learn(
        total_timesteps=policy_cfg["total_timestep"],
        reset_num_timesteps=True,
        progress_bar=True,
        tb_log_name=run_name,
        callback=callbacks,
    )
    # Save final model
    model.save(f"{model_path}/final_model")

    vec_env.close()

    del model
    del eval_callback
    del vec_env

    gc.collect()

def eval_run():
    # Test
    import time
    from tqdm.auto import tqdm

    ep_len = 0
    importlib.reload(go1_env)
    model_path = f"{repo_dir}/models/{model_name}/final_model.zip"
    print(f"Loading model from {model_path}")
    WIDTH, HEIGHT = 320, 240

    # Set a fixed command for testing [vx (m/s), vy (m/s), wz (rad/s)]
    given_command = [0.8, 0.0, 0.0]

    go1_env.Go1MujocoEnv._get_obs = _get_obs_with_phase if use_phase else _get_obs_without_phase

    env = go1_env.Go1MujocoEnv(
        prj_path=f"{repo_dir}",
        cfg_path=f"{repo_dir}/models/{model_name}/envs.yaml",
        given_command=given_command,  # Use fixed command instead of random
        render_mode="rgb_array",
        camera_name="tracking",
        width=WIDTH,
        height=HEIGHT,
    )



    env._reset_noise_scale = 0.05 # reduce intial random noise

    inter_frame_sleep = 0.0

    model = PPO.load(path=model_path, env=env, verbose=1)

    video_path = f"{repo_dir}/../rollout_{model_name}.mp4"

    obs, _ = env.reset()
    max_time_step_s = policy_cfg["test"]["max_time_step_s"]
    ep_len = 0
    t_render = 0.0
    n_render = 0
    last_render = 0.0
    start = time.perf_counter()
    video_fps = 10

    # Ctrl Hz: 50
    render_interval = 50 // video_fps
    max_steps = int(max_time_step_s * 50)

    writer = imageio.get_writer(
        video_path,
        fps=video_fps,
        codec="libx264",
        quality=8,
        pixelformat="yuv420p",
    )

    frames = []
    pbar = tqdm(total=max_steps, desc="rollout", unit="step", dynamic_ncols=True)

    print("max time:", max_time_step_s)
    print("max step: ", max_steps)

    while ep_len < max_steps:
      with torch.no_grad():
        action, _ = model.predict(obs, deterministic=True)
      obs, reward, terminated, truncated, info = env.step(action)

      if ep_len % render_interval == 0:
        t0 = time.perf_counter()
        frame = env.render()
        frames.append(frame)
        current_dur = time.perf_counter() - t0
        t_render += current_dur
        n_render += 1

      # ---- status bar 업데이트 ----
      elapsed = time.perf_counter() - start
      steps_per_sec = ep_len / max(elapsed, 1e-9)
      avg_render = (t_render / n_render) if n_render else 0.0

      pbar.set_postfix({
          "steps/s": f"{steps_per_sec:6.1f}",
          "renders": n_render,
          "r_last(s)": f"{last_render:5.3f}",
          "r_avg(s)": f"{avg_render:5.3f}",
      })
      pbar.update(1)


      ep_len += 1

    imageio.mimwrite(
        video_path,
        frames,
        fps=video_fps,
        codec="libx264",
        quality=8,
        pixelformat="yuv420p",
    )

    env.close()

    print("avg render sec:", t_render / max(n_render, 1))
    print("Saved video to:", video_path)

    return video_path
# Out:
# 12
# 64
# Observation shape: (48,)
#
# Action space: Box([-0.863     -1.3859999 -1.218     -0.863     -1.3859999 -1.218
#  -0.863     -1.586     -1.218     -0.863     -1.586     -1.218    ], [0.863     3.8009999 0.712     0.863     3.8009999 0.712     0.863
#  3.6009998 0.712     0.863     3.6009998 0.712    ], (12,), float32)
#
# Observation space: Box(-inf, inf, (48,), float32)

# %% [markdown]
# ## 1-3. 실험 선택
#
# 진행할 실험 블럭을 실행합니다.
#
# 사용하는 Reward, Reward coef등을 각 실험에 맞게 조정합니다. 미리 체크포인트 안쪽에 사용했던 세팅 yaml 파일을 넣어놓았습니다. 이를 불러와 src/envs.yaml 을 대체합니다.
#
# 만약 새로운 reward func를 추가하거나 변경하고 싶다면, src/mdp/reward.py, go1_mujoco_env.py 내부의 _get_reward() 및 src/envs.yaml을 수정합니다.

# %% [markdown]
# ### 실험 1 : Task Reward (Velocity Tracking) 과 Termination Reward만 있는 가장 단순한 경우

# %%
# 실험 1
use_phase = False
model_name = "pretrained"
env_cfg_path = f"{repo_dir}/models/pretrained/envs.yaml"

show_code(env_cfg_path, title= model_name + " yaml", max_height=800)
# Out:
#
#     <style>
#     .highlight pre { margin: 0; text-align: left; }
#     </style>
#
#     <details>
#       <summary>pretrained yaml</summary>
#       <div style="margin-top:8px; margin-left:16px; max-height:800px; overflow:auto; border:1px solid #ddd; padding:10px; background:transparent;">
#         <div class="highlight" style="background: #f0f0f0"><pre style="line-height: 125%;"><span></span><span style="color: #666666; background-color: transparent; padding-left: 5px; padding-right: 5px;"> 1</span><span style="color: #60A0B0; font-style: italic"># Positive Rewards</span>
# <span style="color: #666666; background-color: transparent; padding-left: 5px; padding-right: 5px;"> 2</span>reward:
# <span style="color: #666666; background-color: transparent; padding-left: 5px; padding-right: 5px;"> 3</span>  linear_vel_tracking: <span style="color: #40A070">1.5</span>
# <span style="color: #666666; background-color: transparent; padding-left: 5px; padding-right: 5px;"> 4</span>  angular_vel_tracking: <span style="color: #40A070">1.0</span>
# <span style="color: #666666; background-color: transparent; padding-left: 5px; padding-right: 5px;"> 5</span>  healthy: <span style="color: #40A070">0.00</span>
# <span style="color: #666666; background-color: transparent; padding-left: 5px; padding-right: 5px;"> 6</span>  base_height: <span style="color: #40A070">0.0</span>
# <span style="color: #666666; background-color: transparent; padding-left: 5px; padding-right: 5px;"> 7</span>  feet_air_time: <span style="color: #40A070">0.0</span>
# <span style="color: #666666; background-color: transparent; padding-left: 5px; padding-right: 5px;"> 8</span><span style="color: #60A0B0; font-style: italic"># Negative Rewards (Penalty)</span>
# <span style="color: #666666; background-color: transparent; padding-left: 5px; padding-right: 5px;"> 9</span>cost:
# <span style="color: #666666; background-color: transparent; padding-left: 5px; padding-right: 5px;">10</span>  torque: <span style="color: #40A070">0.001</span>
# <span style="color: #666666; background-color: transparent; padding-left: 5px; padding-right: 5px;">11</span>  vertical_vel: <span style="color: #40A070">0.0</span>
# <span style="color: #666666; background-color: transparent; padding-left: 5px; padding-right: 5px;">12</span>  xy_angular_vel: <span style="color: #40A070">0.0</span>
# <span style="color: #666666; background-color: transparent; padding-left: 5px; padding-right: 5px;">13</span>  action_rate: <span style="color: #40A070">0.0</span>
# <span style="color: #666666; background-color: transparent; padding-left: 5px; padding-right: 5px;">14</span>  joint_limit: <span style="color: #40A070">0.0</span>
# <span style="color: #666666; background-color: transparent; padding-left: 5px; padding-right: 5px;">15</span>  joint_acc: <span style="color: #40A070">0.0</span>
# <span style="color: #666666; background-color: transparent; padding-left: 5px; padding-right: 5px;">16</span>  action_norm: <span style="color: #40A070">0.0</span>  <span style="color: #60A0B0; font-style: italic"># Penalize action norm magnitude</span>
# <span style="color: #666666; background-color: transparent; padding-left: 5px; padding-right: 5px;">17</span>  joint_pos_deviation: <span style="color: #40A070">0.0</span>  <span style="color: #60A0B0; font-style: italic"># Penalize joint position deviation from nominal pose</span>
# <span style="color: #666666; background-color: transparent; padding-left: 5px; padding-right: 5px;">18</span>  gait_enforcement: <span style="color: #40A070">0.0</span>  <span style="color: #60A0B0; font-style: italic"># Enforce trot gait pattern</span>
# <span style="color: #666666; background-color: transparent; padding-left: 5px; padding-right: 5px;">19</span>  foot_clearance: <span style="color: #40A070">0.0</span>  <span style="color: #60A0B0; font-style: italic"># Enforce foot clearance during swing phase</span>
# <span style="color: #666666; background-color: transparent; padding-left: 5px; padding-right: 5px;">20</span><span style="color: #60A0B0; font-style: italic"># Environment</span>
# <span style="color: #666666; background-color: transparent; padding-left: 5px; padding-right: 5px;">21</span>env:
# <span style="color: #666666; background-color: transparent; padding-left: 5px; padding-right: 5px;">22</span>  max_episode_length_s: <span style="color: #40A070">15.0</span>
# <span style="color: #666666; background-color: transparent; padding-left: 5px; padding-right: 5px;">23</span><span style="color: #60A0B0; font-style: italic"># Curriculum</span>
# <span style="color: #666666; background-color: transparent; padding-left: 5px; padding-right: 5px;">24</span>curriculum:
# <span style="color: #666666; background-color: transparent; padding-left: 5px; padding-right: 5px;">25</span>  base: <span style="color: #40A070">0.3</span>
# <span style="color: #666666; background-color: transparent; padding-left: 5px; padding-right: 5px;">26</span><span style="color: #60A0B0; font-style: italic"># Command</span>
# <span style="color: #666666; background-color: transparent; padding-left: 5px; padding-right: 5px;">27</span>command:
# <span style="color: #666666; background-color: transparent; padding-left: 5px; padding-right: 5px;">28</span>  tracking_velocity_sigma: <span style="color: #40A070">0.25</span>
# <span style="color: #666666; background-color: transparent; padding-left: 5px; padding-right: 5px;">29</span>  des_vel:
# <span style="color: #666666; background-color: transparent; padding-left: 5px; padding-right: 5px;">30</span>    <span style="color: #007020">min</span>: [<span style="color: #40A070">0.2</span>, <span style="color: #40A070">0.0</span>, <span style="color: #40A070">0.0</span>]
# <span style="color: #666666; background-color: transparent; padding-left: 5px; padding-right: 5px;">31</span>    <span style="color: #007020">max</span>: [<span style="color: #40A070">1.0</span>, <span style="color: #40A070">0.0</span>, <span style="color: #40A070">0.0</span>]
# <span style="color: #666666; background-color: transparent; padding-left: 5px; padding-right: 5px;">32</span><span style="color: #60A0B0; font-style: italic"># Gait</span>
# <span style="color: #666666; background-color: transparent; padding-left: 5px; padding-right: 5px;">33</span>gait:
# <span style="color: #666666; background-color: transparent; padding-left: 5px; padding-right: 5px;">34</span>  gait_hz: <span style="color: #40A070">0.5</span>
# <span style="color: #666666; background-color: transparent; padding-left: 5px; padding-right: 5px;">35</span>  gait_shift: [<span style="color: #40A070">1.0</span>, <span style="color: #40A070">0.0</span>, <span style="color: #40A070">0.0</span>, <span style="color: #40A070">1.0</span>] <span style="color: #60A0B0; font-style: italic">#[RR, RL, FR, FL] shift, Trot</span>
# <span style="color: #666666; background-color: transparent; padding-left: 5px; padding-right: 5px;">36</span><span style="color: #60A0B0; font-style: italic">#  gait_shift: [1.0, 1.0, 0.0, 0.0] #[RR, RL, FR, FL] shift, Bound</span>
# <span style="color: #666666; background-color: transparent; padding-left: 5px; padding-right: 5px;">37</span><span style="color: #60A0B0; font-style: italic"># Observation</span>
# <span style="color: #666666; background-color: transparent; padding-left: 5px; padding-right: 5px;">38</span>observation:
# <span style="color: #666666; background-color: transparent; padding-left: 5px; padding-right: 5px;">39</span>  linear_velocity: <span style="color: #40A070">2.0</span>
# <span style="color: #666666; background-color: transparent; padding-left: 5px; padding-right: 5px;">40</span>  angular_velocity: <span style="color: #40A070">0.25</span>
# <span style="color: #666666; background-color: transparent; padding-left: 5px; padding-right: 5px;">41</span>  dofs_position: <span style="color: #40A070">1.0</span>
# <span style="color: #666666; background-color: transparent; padding-left: 5px; padding-right: 5px;">42</span>  dofs_velocity: <span style="color: #40A070">0.05</span>
# <span style="color: #66

# %% [markdown]
# ### 실험 1-1: 실험 1의 세팅에서 Torque Regularization Reward가 추가된 경우

# %%
# 실험 1
use_phase = False
model_name = "pretrained_0.5"
env_cfg_path = f"{repo_dir}/models/pretrained_0.5/envs.yaml"

show_code(env_cfg_path, title= model_name + " yaml", max_height=800)

# %% [markdown]
# ### 실험 1-2: 실험 1-1의 세팅에서 Calf Contact 시 Early Termination 시키는 경우

# %%
# 실험 1
use_phase = False
model_name = "pretrained_0.5_earlytermination"
env_cfg_path = f"{repo_dir}/models/pretrained_0.5_earlytermination/envs.yaml"

show_code(env_cfg_path, title= model_name + " yaml", max_height=800)

# %% [markdown]
# ### 실험 2 : 실험 1-2의 세팅에서 기본적인 Regularization Reward가 추가된 경우

# %%
use_phase = False
model_name = "pretrained2"
env_cfg_path = f"{repo_dir}/models/pretrained2/envs.yaml"

show_code(env_cfg_path, title= model_name + " yaml", max_height=800)

# %% [markdown]
# ### 실험 3: 실험 2의 세팅에서 Motion 및 Gait Regularization Reward 추가된 경우

# %%
use_phase = True
model_name = "pretrained3"
env_cfg_path = f"{repo_dir}/models/pretrained3/envs.yaml"

show_code(env_cfg_path, title= model_name + " yaml", max_height=800)

# %% [markdown]
# ---
# ## 2. Training

# %%
train_run(env_cfg_path=env_cfg_path)

# %% [markdown]
# ---
# ## 3. Evaluation
#
# 학습한 policy를 확인합니다.
#
# 실습 시간에는 아래 Pretrained된 정책을 이용하여 학습 결과를 확인합니다.

# %%
video_path = eval_run()
# Out:
# Loading model from /home/jaehyun/etc_ws/RL_DEMO/notebooks/RL_DEMO/models/pretrained/final_model.zip
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# rollout:   0%|          | 0/200 [00:00<?, ?step/s]
# max time: 4.0
# max step:  200
# avg render sec: 0.0031242349039530383
# Saved video to: /home/jaehyun/etc_ws/RL_DEMO/notebooks/RL_DEMO/../rollout_pretrained.mp4

# %%
display(
    Video(
        video_path,
        embed=True,
        html_attributes="controls autoplay loop"
    )
)
# Out:
# <video controls autoplay loop  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %% [markdown]
# ---
#
# ## 4. 결과 비교
#
# 각 실험에 대하여 Training 및 Evaluation을 진행 한 뒤, 결과를 비교합니다.
#
# 실습 시간에는 미리 학습된 pretrained model로 Evaluation만 진행한 후, 결과를 비교합니다.

# %%
import base64
from IPython.display import HTML
from pathlib import Path

def video_embed(path, caption, width=320, autoplay=True):
    data = Path(path).read_bytes()
    b64 = base64.b64encode(data).decode("ascii")
    attrs = "controls"
    if autoplay:
        attrs += " autoplay muted loop"
    return f"""
    <figure style="margin:0; text-align:center;">
      <video {attrs} width="{width}">
        <source src="data:video/mp4;base64,{b64}" type="video/mp4">
      </video>
      <figcaption style="margin-top:6px; font-size:12px;">{caption}</figcaption>
    </figure>
    """

videos = [
    (f"{repo_dir}/../rollout_pretrained.mp4",  "Pretrained 1: (Task + Termination)"),
    (f"{repo_dir}/../rollout_pretrained_0.5.mp4",  "Pretrained 1-1: (Task + Termination + Torque Reg)"),
    (f"{repo_dir}/../rollout_pretrained_0.5_earlytermination.mp4",  "Pretrained 1-2: Pre 1-1 + (Calf Contact Early Termination)"),
    (f"{repo_dir}/../rollout_pretrained2.mp4", "Pretrained 2: (Pre 1-2 + Basic Regularization)"),
    (f"{repo_dir}/../rollout_pretrained3.mp4", "Pretrained 3: (Pre 2 + Motion / Gait Regularization)"),
]

HTML(f"""
<div style="display:flex; gap:12px;">
  {''.join([video_embed(p, cap, width=320) for p, cap in videos])}
</div>
""")
