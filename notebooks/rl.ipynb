# %%
import os
os.chdir("/content")
# !pwd
# Out:
# /content

# %%
import importlib
from rl_debug import rl_test
importlib.reload(rl_test)
rl_test.print_hi(name="ho")
rl_test.print_ho()
# Out:
# ho
# ho2
