# %%
# Clone repository
import os
os.chdir("/content")
if not os.path.isdir("RL_DEMO"):
  # !git clone https://github.com/Kyu3224/RL_DEMO.git
else:
  print("Cloned Directory already exists")

# %cd RL_DEMO
print("Current Directory: ", os.getcwd())
# Out:
# Cloning into 'RL_DEMO'...
# remote: Enumerating objects: 18, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 18 (delta 2), reused 11 (delta 1), pack-reused 0 (from 0)
# Receiving objects: 100% (18/18), done.
# Resolving deltas: 100% (2/2), done.
# /content/RL_DEMO
# Current Directory:  /content/RL_DEMO

# %%
# Out:
# ho
# ho2
